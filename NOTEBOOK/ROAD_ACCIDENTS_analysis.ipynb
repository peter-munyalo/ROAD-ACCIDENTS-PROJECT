# %% [markdown]
# ## Spatio-Temporal Analysis of Road Traffic Crashes in Kenya: Evidence from Geo-Referenced Accident Report

# %% [markdown]
# ### PHASE 1: Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\leovo\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\leovo\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\leovo\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\leovo\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\leovo\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\leovo\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\leovo\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\leovo\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leovo\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leovo\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leovo\anaconda3\lib\site-packages (from requests->folium) (2025.11.12)

# %%
import folium

# %% [markdown]
# ## PHASE 2: Data Loading & Inspection

# %%
df = pd.read_csv("ma3route_crashes_manualcode.csv")

df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2595 entries, 0 to 2594
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   crash_id                   2595 non-null   int64
#  1   crash_datetime             2595 non-null   object
#  2   crash_date                 2595 non-null   object
#  3   latitude                   2595 non-null   float64
#  4   longitude                  2595 non-null   float64
#  5   n_crash_reports            2595 non-null   int64
#  6   contains_fatality_words    2595 non-null   int64
#  7   contains_pedestrian_words  2595 non-null   int64
#  8   contains_matatu_words      2595 non-null   int64
#  9   contains_motorcycle_words  2595 non-null   int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 202.9+ KB
#           crash_id     latitude    longitude  n_crash_reports  \
# count  2595.000000  2595.000000  2595.000000      2595.000000
# mean   1573.075530    -1.271065    36.861475         1.583815
# std     912.156283     0.281333     0.305962         2.421514
# min       1.000000    -4.059868    34.145808         1.000000
# 25%     729.500000    -1.319624    36.807140         1.000000
# 50%    1644.000000    -1.269274    36.854319         1.000000
# 75%    2292.500000    -1.234151    36.899491         1.000000
# max    3115.000000     1.257331    40.171389        67.000000
#
#        contains_fatality_words  contains_pedestrian_words  \
# count              2595.000000                2595.000000
# mean                  0.063969                   0.023507
# std                   0.244745                   0.151536
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   1.000000                   1.000000
#
#        contains_matatu_words  contains_motorcycle_words
# count            2595.000000                2595.000000
# mean                0.080539                   0.036609
# std                 0.272179                   0.187836
# min                 0.000000                   0.000000
# 25%                 0.000000                   0.000000
# 50%                 0.000000                   0.000000
# 75%                 0.000000                   0.000000
# max                 1.000000                   1.000000

# %% [markdown]
# ### PHASE 3: Data Cleaning & Feature Engineering

# %%
df['crash_datetime'] = pd.to_datetime(df['crash_datetime'])
df['crash_date'] = pd.to_datetime(df['crash_date'])

# %% [markdown]
# Extract time features

# %%
df['hour'] = df['crash_datetime'].dt.hour
df['day_of_week'] = df['crash_datetime'].dt.day_name()
df['month'] = df['crash_datetime'].dt.month

# %% [markdown]
# ### PHASE 4: Descriptive Analysis

# %% [markdown]
# Accident frequency

# %%
df.shape[0]
# Out:
# 2595

# %% [markdown]
# Fatal vs non-fatal

# %%
df['contains_fatality_words'].value_counts(normalize=True) * 100
# Out:
# contains_fatality_words
# 0    93.603083
# 1     6.396917
# Name: proportion, dtype: float64

# %% [markdown]
# Pie chart

# %%
counts = df['contains_fatality_words'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90,
        colors=['green', 'red'])
plt.title('Fatal vs Non-Fatal Road Traffic Accidents')
plt.axis('equal')

plt.show()

# %%
#import pandas as pd
#import matplotlib.pyplot as plt

# Load dataset
#df = pd.read_csv('/mnt/data/824d9b24-e377-43ab-ad53-fe9cfd45a58b.csv')

# Helper function to create pie charts
def plot_user_severity(user_col, user_label):
    subset = df[df[user_col] == 1]
    severity = subset['contains_fatality_words'].map({1:'Fatal', 0:'Non-Fatal'}).value_counts()
    
    plt.figure(figsize=(5,5))
    plt.pie(
        severity,
        labels=[f"{label} ({count})" for label, count in zip(severity.index, severity.values)],
        autopct='%1.1f%%',
        startangle=90
    )
    plt.title(f"{user_label} Crash Severity (Fatal vs Non-Fatal)")
    plt.show()
    print(f"Total {user_label} Crashes:", len(subset))
    print(severity, "\n")

# %%
# Convert severity indicator to labels
severity = df['contains_fatality_words'].map({1:'Fatal', 0:'Non-Fatal'}).value_counts()

# Create pie chart with counts + percentages
plt.figure(figsize=(6,6))
plt.pie(
    severity,
    labels=[f"{label} ({count})" for label, count in zip(severity.index, severity.values)],
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Fatal vs Non-Fatal Crashes Road Traffic Accidents")
plt.show()

# %%
# Road user counts from indicator columns
road_user_counts = {
    'Pedestrian': df['contains_pedestrian_words'].sum(),
    'Matatu': df['contains_matatu_words'].sum(),
    'Motorcycle': df['contains_motorcycle_words'].sum()
}

print("🚗 Number of Crashes by Road User:")
print(pd.Series(road_user_counts))
# Out:
# 🚗 Number of Crashes by Road User:
# Pedestrian     61
# Matatu        209
# Motorcycle     95
# dtype: int64

# %%
#import matplotlib.pyplot as plt

pd.Series(road_user_counts).plot(kind='bar')
plt.title("Number of Crashes by Road User Category")
plt.xlabel("Road User Type")
plt.ylabel("Number of Crashes")
plt.xticks(rotation=0)
plt.show()

# %%
fatal_vs_nonfatal = df['contains_fatality_words'].map({1:'Fatal', 0:'Non-Fatal'}).value_counts()

print("\n☠️ Fatal vs Non-Fatal Crashes:")
print(fatal_vs_nonfatal)
# Out:
# ☠️ Fatal vs Non-Fatal Crashes:
# contains_fatality_words
# Non-Fatal    2429
# Fatal         166
# Name: count, dtype: int64

# %%
#import pandas as pd

#df = pd.read_csv('/mnt/data/824d9b24-e377-43ab-ad53-fe9cfd45a58b.csv')

unclassified_fatal = df[
    (df['contains_fatality_words'] == 1) &
    (df[['contains_pedestrian_words', 'contains_matatu_words', 'contains_motorcycle_words']].sum(axis=1) == 0)
]

print("Fatal crashes with NO category:", len(unclassified_fatal))
# Out:
# Fatal crashes with NO category: 114

# %%
#import pandas as pd
#import matplotlib.pyplot as plt

# Load data
#df = pd.read_csv('/mnt/data/824d9b24-e377-43ab-ad53-fe9cfd45a58b.csv')

# Fatal crashes filtered
fatal = df[df['contains_fatality_words'] == 1]

# Count fatalities per user type
matatu_fatal = fatal['contains_matatu_words'].sum()
pedestrian_fatal = fatal['contains_pedestrian_words'].sum()
motorcycle_fatal = fatal['contains_motorcycle_words'].sum()

# Fatal crashes with NO identified category
unclassified_fatal = len(fatal) - (matatu_fatal + pedestrian_fatal + motorcycle_fatal)

# Create dataset for chart
labels = ['Matatu', 'Pedestrian', 'Motorcycle', 'Unclassified']
values = [matatu_fatal, pedestrian_fatal, motorcycle_fatal, unclassified_fatal]

# Plot bar chart
plt.figure(figsize=(8,5))
plt.bar(labels, values)
plt.title("Fatal Crashes by Road User Category (Including Unclassified)")
plt.xlabel("Road User Category")
plt.ylabel("Number of Fatal Crashes")
plt.show()

# Print summary counts
print("Fatal Crash Breakdown:")
for l, v in zip(labels, values):
    print(f"{l}: {v}")
print("\nTotal Fatal Crashes:", sum(values))
# Out:
# Fatal Crash Breakdown:
# Matatu: 14
# Pedestrian: 21
# Motorcycle: 19
# Unclassified: 112
#
# Total Fatal Crashes: 166

# %% [markdown]
# Vehicle involvement

# %%
df[['contains_pedestrian_words',
    'contains_matatu_words',
    'contains_motorcycle_words']].mean()*100
# Out:
# contains_pedestrian_words    2.350674
# contains_matatu_words        8.053950
# contains_motorcycle_words    3.660886
# dtype: float64

# %%
# Sum crashes for each road user category
categories = {
    'Pedestrian': df.loc[df['contains_pedestrian_words'] == 1, 'n_crash_reports'].sum(),
    'Matatu': df.loc[df['contains_matatu_words'] == 1, 'n_crash_reports'].sum(),
    'Motorcycle': df.loc[df['contains_motorcycle_words'] == 1, 'n_crash_reports'].sum()
}

# Convert to DataFrame
category_df = pd.DataFrame.from_dict(categories, orient='index', columns=['Number of Crashes'])

# Plot bar chart
plt.figure(figsize=(8, 6))
category_df.plot(kind='bar', legend=False, color='steelblue')

plt.title('Distribution of Road Traffic Crashes by Road User Category')
plt.xlabel('Road User Category')
plt.ylabel('Number of Crash Reports')
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### CORRELATION ANALYSIS

# %%
corr_df = df[
    ['contains_fatality_words',
     'contains_pedestrian_words',
     'contains_motorcycle_words',
     'contains_matatu_words',
     'n_crash_reports',
     'hour']
]

# %%
correlation_matrix = corr_df.corr(method='pearson')
correlation_matrix
# Out:
#                            contains_fatality_words  contains_pedestrian_words  \
# contains_fatality_words                   1.000000                   0.177723
# contains_pedestrian_words                 0.177723                   1.000000
# contains_motorcycle_words                 0.108367                   0.010386
# contains_matatu_words                     0.003648                   0.019508
# n_crash_reports                           0.182839                   0.040329
# hour                                     -0.000516                   0.013532
#
#                            contains_motorcycle_words  contains_matatu_words  \
# contains_fatality_words                     0.108367               0.003648
# contains_pedestrian_words                   0.010386               0.019508
# contains_motorcycle_words                   1.000000              -0.004911
# contains_matatu_words                      -0.004911               1.000000
# n_crash_reports                            -0.008020               0.138613
# hour                                        0.002423              -0.036443
#
#                            n_crash_reports      hour
# contains_fatality_words           0.182839 -0.000516
# contains_pedestrian_words         0.040329  0.013532
# contains_motorcycle_words        -0.008020  0.002423
# contains_matatu_words             0.138613 -0.036443
# n_crash_reports                   1.000000 -0.060439
# hour                             -0.060439  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)
plt.title("Correlation Matrix of Road Accident Variables")
plt.show()

# %% [markdown]
# ### PHASE 5: Temporal Analysis

# %% [markdown]
# Accidents by hour

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# Create a month name column
df['month_name'] = df['month'].apply(lambda x: calendar.month_name[x])

# Ensure correct month order
month_order = list(calendar.month_name)[1:]  # January to December

plt.figure(figsize=(10, 6))
sns.countplot(x='month_name', data=df, order=month_order)

plt.title("Road Traffic Accidents by Month")
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Accidents by day

# %%
plt.figure()
sns.countplot(x='day_of_week', data=df,
              order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title("Road Accidents by Day of Week")
plt.show()

# %% [markdown]
# ### PHASE 6: Severity & Risk Factor Analysis
# Fatality vs road users

# %%
pd.crosstab(df['contains_fatality_words'],
            df['contains_motorcycle_words'],
            normalize='columns') * 100
# Out:
# contains_motorcycle_words      0     1
# contains_fatality_words
# 0                          94.12  80.0
# 1                           5.88  20.0

# %% [markdown]
# Fatalty vs Pedestrians

# %%
pd.crosstab(df['contains_fatality_words'],
            df['contains_pedestrian_words'],
            normalize='columns') * 100
# Out:
# contains_pedestrian_words          0         1
# contains_fatality_words
# 0                          94.277822  65.57377
# 1                           5.722178  34.42623

# %% [markdown]
# Fatality vs Matatus

# %%
#import pandas as pd

#df = pd.read_csv('/mnt/data/824d9b24-e377-43ab-ad53-fe9cfd45a58b.csv')

# Filter only Matatu-related crashes
matatu_df = df[df['contains_matatu_words'] == 1]

# Count fatal vs non-fatal
matatu_severity_count = matatu_df['contains_fatality_words'].map({1: 'Fatal', 0: 'Non-Fatal'}).value_counts()

print("Matatu Crash Severity Counts:")
print(matatu_severity_count)

# Also show total Matatu crashes
print("\nTotal Matatu Crashes:", len(matatu_df))
# Out:
# Matatu Crash Severity Counts:
# contains_fatality_words
# Non-Fatal    195
# Fatal         14
# Name: count, dtype: int64
#
# Total Matatu Crashes: 209

# %%
#import pandas as pd

#df = pd.read_csv('/mnt/data/824d9b24-e377-43ab-ad53-fe9cfd45a58b.csv')

# Function to get severity counts for a road user
def severity_count(user_col, user_label):
    subset = df[df[user_col] == 1]
    counts = subset['contains_fatality_words'].map({1:'Fatal', 0:'Non-Fatal'}).value_counts()
    print(f"{user_label} Crash Severity Counts:")
    print(counts)
    print("Total", user_label, "Crashes:", len(subset), "\n")

# 🚐 Matatu
severity_count('contains_matatu_words', 'Matatu')

# 🚶 Pedestrian
severity_count('contains_pedestrian_words', 'Pedestrian')

# 🏍️ Motorcycle
severity_count('contains_motorcycle_words', 'Motorcycle')
# Out:
# Matatu Crash Severity Counts:
# contains_fatality_words
# Non-Fatal    195
# Fatal         14
# Name: count, dtype: int64
# Total Matatu Crashes: 209
#
# Pedestrian Crash Severity Counts:
# contains_fatality_words
# Non-Fatal    40
# Fatal        21
# Name: count, dtype: int64
# Total Pedestrian Crashes: 61
#
# Motorcycle Crash Severity Counts:
# contains_fatality_words
# Non-Fatal    76
# Fatal        19
# Name: count, dtype: int64
# Total Motorcycle Crashes: 95

# %%
pd.crosstab(df['contains_fatality_words'],
            df['contains_matatu_words'],
            normalize='columns') * 100
# Out:
# contains_matatu_words            0          1
# contains_fatality_words
# 0                        93.629505  93.301435
# 1                         6.370495   6.698565

# %% [markdown]
# ### PHASE 7: Spatial (Hotspot) Analysis

# %% [markdown]
# Create accident map

# %%
m = folium.Map(location=[df.latitude.mean(), df.longitude.mean()],
               zoom_start=7)

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=3,
        color='red' if row['contains_fatality_words'] == 1 else 'blue',
        fill=True
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6760e62fde058fa406d90e3e46f4e79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6760e62fde058fa406d90e3e46f4e79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6760e62fde058fa406d90e3e46f4e79 = L.map(
#                 &quot;map_a6760e62fde058fa406d90e3e46f4e79&quot;,
#                 {
#                     center: [-1.2710651453605504, 36.861474550809646],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8d5233e73c3393e77db5651ea110a93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8d5233e73c3393e77db5651ea110a93.addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_6aefb455ac8246d0e318fcb7d9d3a5bc = L.circleMarker(
#                 [-1.2631315, 36.7642835],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_e503812e3f6a3def9003f046085cdf07 = L.circleMarker(
#                 [-1.295135, 36.821932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_fa293b63dd93fb4ea32111684aa6a4c7 = L.circleMarker(
#                 [-1.3718555, 36.9204565],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_c2e57e5a95c924b357e6a2888b2a6f60 = L.circleMarker(
#                 [-1.209945, 36.83323],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_edb59167f6fb5f0de9746baa5049f676 = L.circleMarker(
#                 [-1.215468, 36.850638],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6760e62fde058fa406d90e3e46f4e79);
#
#
#             var circle_marker_6b656888f1ee1af258eb13fe137bd644 = L.circleMarker(
#                 [-1.2451285, 36.8673795],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &

# %%
# !pip install contextily
# Out:
# Requirement already satisfied: contextily in c:\users\leovo\anaconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: geopy in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (3.10.6)
# Requirement already satisfied: mercantile in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (12.0.0)
# Requirement already satisfied: rasterio in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (1.4.4)
# Requirement already satisfied: requests in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (2.32.5)
# Requirement already satisfied: joblib in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (1.5.2)
# Requirement already satisfied: xyzservices in c:\users\leovo\anaconda3\lib\site-packages (from contextily) (2025.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\leovo\anaconda3\lib\site-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leovo\anaconda3\lib\site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\leovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Requirement already satisfied: click>=3.0 in c:\users\leovo\anaconda3\lib\site-packages (from mercantile->contextily) (8.3.1)
# Requirement already satisfied: colorama in c:\users\leovo\anaconda3\lib\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: affine in c:\users\leovo\anaconda3\lib\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\leovo\anaconda3\lib\site-packages (from rasterio->contextily) (25.4.0)
# Requirement already satisfied: certifi in c:\users\leovo\anaconda3\lib\site-packages (from rasterio->contextily) (2025.11.12)
# Requirement already satisfied: cligj>=0.5 in c:\users\leovo\anaconda3\lib\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\leovo\anaconda3\lib\site-packages (from rasterio->contextily) (1.1.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\leovo\anaconda3\lib\site-packages (from requests->contextily) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\leovo\anaconda3\lib\site-packages (from requests->contextily) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\leovo\anaconda3\lib\site-packages (from requests->contextily) (2.5.0)

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\leovo\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (2.3.5)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\leovo\anaconda3\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leovo\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leovo\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leovo\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\leovo\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\leovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)

# %%
from folium.plugins import HeatMap

# %%
# Create base map
m = folium.Map(
    location=[df['latitude'].mean(), df['longitude'].mean()],
    zoom_start=11,
    tiles='OpenStreetMap'
)

# Create heat data
heat_data = [[row['latitude'], row['longitude']] for _, row in df.iterrows()]

# Add heatmap
HeatMap(
    heat_data,
    radius=15,
    blur=20,
    max_zoom=13
).add_to(m)

# Save map
m.save("accident_hotspot_map.html")

# %% [markdown]
# ### PHASE 8: Reporting Intensity Analysis

# %%
df.groupby('contains_fatality_words')['n_crash_reports'].mean()
# Out:
# contains_fatality_words
# 0    1.468094
# 1    3.277108
# Name: n_crash_reports, dtype: float64

# %% [markdown]
# Fatal crashes usually generate more reports

# %% [markdown]
# ### PHASE 9:  Simple Predictive Model

# %% [markdown]
# Predict fatality likelihood:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = df[['contains_pedestrian_words',
        'contains_matatu_words',
        'contains_motorcycle_words',
        'n_crash_reports']]

y = df['contains_fatality_words']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = LogisticRegression()
model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.938382541720154

# %% [markdown]
#  Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

X = df[
    ['contains_pedestrian_words',
     'contains_motorcycle_words',
     'contains_matatu_words',
     'n_crash_reports',
     'hour']
]

y = df['contains_fatality_words']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, y_train)

y_pred = log_model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97       726
#            1       1.00      0.02      0.04        53
#
#     accuracy                           0.93       779
#    macro avg       0.97      0.51      0.50       779
# weighted avg       0.94      0.93      0.90       779

# %%
import numpy as np

odds_ratios = pd.DataFrame({
    'Variable': X.columns,
    'Odds_Ratio': np.exp(log_model.coef_[0])
})

odds_ratios
# Out:
#                     Variable  Odds_Ratio
# 0  contains_pedestrian_words    4.398553
# 1  contains_motorcycle_words    3.931076
# 2      contains_matatu_words    0.690084
# 3            n_crash_reports    1.159572
# 4                       hour    0.999518

# %% [markdown]
# Interpretation

# %% [markdown]
# ### Pedestrian Involvement
# “Crashes involving pedestrians exhibited higher odds of being fatal, highlighting the vulnerability of pedestrians within the Kenyan road transport environment.”
#
# ### Motorcycle Involvement
# “Motorcycle involvement significantly increased the likelihood of fatal outcomes, reflecting limited physical protection and increased exposure among motorcyclists.”
#
# ### Matatu Involvement
# “Matatu involvement showed a weaker association with fatality, suggesting that vehicle size and passenger safety features may moderate crash severity.”
#
# ### Number of Crash Reports
# “An increase in the number of crash reports was associated with higher odds of fatality, indicating that reporting intensity may serve as a proxy for crash severity.”
#
# ### Hour of Occurrence
# “Time of occurrence demonstrated a relatively small effect on fatality likelihood, suggesting that crash severity is more strongly influenced by road user type than by time alone.”

# %% [markdown]
# ### poisson regression

# %%
import statsmodels.api as sm

X_pois = df[
    ['contains_fatality_words',
     'contains_pedestrian_words',
     'contains_motorcycle_words',
     'contains_matatu_words']
]

X_pois = sm.add_constant(X_pois)
y_pois = df['n_crash_reports']

poisson_model = sm.GLM(
    y_pois,
    X_pois,
    family=sm.families.Poisson()
).fit()

print(poisson_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        n_crash_reports   No. Observations:                 2595
# Model:                            GLM   Df Residuals:                     2590
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4170.4
# Date:                Tue, 24 Feb 2026   Deviance:                       2593.3
# Time:                        12:51:23   Pearson chi2:                 5.47e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1458
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.3252      0.018     17.986      0.000       0.290       0.361
# contains_fatality_words       0.8086      0.047     17.048      0.000       0.716       0.902
# contains_pedestrian_words     0.0478      0.090      0.533      0.594      -0.128       0.223
# contains_motorcycle_words    -0.2018      0.086     -2.338      0.019      -0.371      -0.033
# contains_matatu_words         0.5984      0.045     13.236      0.000       0.510       0.687
# =============================================================================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
# Convert date
df['crash_date'] = pd.to_datetime(df['crash_date'])

# Create time features
df['day_of_week'] = df['crash_date'].dt.dayofweek
df['month'] = df['crash_date'].dt.month

# Rename road user indicators for clarity
df['pedestrian'] = df['contains_pedestrian_words']
df['motorcyclist'] = df['contains_motorcycle_words']
df['matatu'] = df['contains_matatu_words']

# Select model variables
df_model = df[[
    'contains_fatality_words',   # Binary outcome
    'pedestrian',
    'motorcyclist',
    'matatu',
    'latitude',
    'longitude',
    'day_of_week',
    'month'
]].dropna()

# %%
y = df_model['contains_fatality_words']

X = df_model.drop('contains_fatality_words', axis=1)

# Add intercept
X = sm.add_constant(X)

# %%
logit_model = sm.Logit(y, X)
logit_results = logit_model.fit()

print(logit_results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.224020
#          Iterations 7
#                               Logit Regression Results
# ===================================================================================
# Dep. Variable:     contains_fatality_words   No. Observations:                 2595
# Model:                               Logit   Df Residuals:                     2587
# Method:                                MLE   Df Model:                            7
# Date:                     Wed, 24 Dec 2025   Pseudo R-squ.:                 0.05776
# Time:                             15:16:53   Log-Likelihood:                -581.33
# converged:                            True   LL-Null:                       -616.97
# Covariance Type:                 nonrobust   LLR p-value:                 8.181e-13
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           22.2710     16.734      1.331      0.183     -10.528      55.070
# pedestrian       2.1661      0.287      7.539      0.000       1.603       2.729
# motorcyclist     1.3861      0.278      4.980      0.000       0.841       1.932
# matatu          -0.0056      0.300     -0.019      0.985      -0.593       0.582
# latitude        -0.4754      0.566     -0.840      0.401      -1.585       0.634
# longitude       -0.6994      0.470     -1.487      0.137      -1.621       0.223
# day_of_week      0.0701      0.043      1.614      0.107      -0.015       0.155
# month           -0.0330      0.026     -1.272      0.203      -0.084       0.018
# ================================================================================

# %%
# Odds Ratios and 95% CI
params = logit_results.params
conf = logit_results.conf_int()

odds_ratios = np.exp(params)
conf_odds = np.exp(conf)

or_table = pd.DataFrame({
    'Odds Ratio': odds_ratios,
    'CI Lower': conf_odds[0],
    'CI Upper': conf_odds[1]
})

print(or_table)
# Out:
#                 Odds Ratio  CI Lower      CI Upper
# const         4.700750e+09  0.000027  8.252654e+23
# pedestrian    8.724355e+00  4.967960  1.532105e+01
# motorcyclist  3.999201e+00  2.317615  6.900892e+00
# matatu        9.943838e-01  0.552473  1.789771e+00
# latitude      6.216475e-01  0.204917  1.885860e+00
# longitude     4.968883e-01  0.197644  1.249206e+00
# day_of_week   1.072588e+00  0.985078  1.167872e+00
# month         9.675769e-01  0.919680  1.017969e+00

# %%
# Predicted probabilities
df_model['pred_prob'] = logit_results.predict(X)

# Predicted classes
df_model['pred_class'] = (df_model['pred_prob'] >= 0.5).astype(int)

# Accuracy
accuracy = (df_model['pred_class'] == y).mean()
print("Classification Accuracy:", accuracy)
# Out:
# Classification Accuracy: 0.935645472061657

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y, df_model['pred_prob'])
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve – Fatal Crash Prediction")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#import pandas as pd
df['n_crash_reports'].mean(), df['n_crash_reports'].var()
# Out:
# (np.float64(1.583815028901734), 5.8637317776460485)

# %%
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm

#df = pd.read_csv("accidents.csv")

# Convert Booleans to numeric
for col in ['contains_pedestrian_words','contains_matatu_words','contains_motorcycle_words','contains_fatality_words']:
    df[col] = df[col].astype(int)

# Convert day names to numbers
day_map = {
    'Monday':1, 'Tuesday':2, 'Wednesday':3,
    'Thursday':4, 'Friday':5, 'Saturday':6, 'Sunday':7
}
df['day_of_week'] = df['day_of_week'].map(day_map)

# Convert numeric columns
df['month'] = df['month'].astype(int)
df['hour'] = df['hour'].astype(int)

# Build Poisson regression model
poisson_model = smf.glm(
    formula="n_crash_reports ~ contains_pedestrian_words + contains_matatu_words + contains_motorcycle_words + hour + day_of_week + month",
    data=df,
    family=sm.families.Poisson()
).fit()

print(poisson_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        n_crash_reports   No. Observations:                 2595
# Model:                            GLM   Df Residuals:                     2588
# Model Family:                 Poisson   Df Model:                            6
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4265.9
# Date:                Tue, 24 Feb 2026   Deviance:                       2784.2
# Time:                        12:53:56   Pearson chi2:                 7.26e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.08057
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.5621      0.051     10.933      0.000       0.461       0.663
# contains_pedestrian_words     0.3347      0.088      3.819      0.000       0.163       0.506
# contains_matatu_words         0.5928      0.045     13.081      0.000       0.504       0.682
# contains_motorcycle_words    -0.0541      0.086     -0.630      0.529      -0.222       0.114
# hour                         -0.0157      0.003     -5.818      0.000      -0.021      -0.010
# day_of_week                  -0.0252      0.008     -3.045      0.002      -0.041      -0.009
# month                         0.0166      0.005      3.402      0.001       0.007       0.026
# =============================================================================================

# %%
y = df['n_crash_reports']

X = df[
    [
        'contains_pedestrian_words',
        'contains_matatu_words',
        'contains_motorcycle_words',
        'hour',
        'day_of_week',
        'month'
    ]
]

X = sm.add_constant(X)

# %%
nb_model = sm.GLM(
    y,
    X,
    family=sm.families.NegativeBinomial()
)

nb_results = nb_model.fit()
print(nb_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        n_crash_reports   No. Observations:                 2595
# Model:                            GLM   Df Residuals:                     2588
# Model Family:        NegativeBinomial   Df Model:                            6
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -4437.2
# Date:                Tue, 24 Feb 2026   Deviance:                       701.68
# Time:                        12:54:03   Pearson chi2:                 2.52e+03
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.02863
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.5461      0.084      6.535      0.000       0.382       0.710
# contains_pedestrian_words     0.3484      0.157      2.221      0.026       0.041       0.656
# contains_matatu_words         0.5827      0.085      6.816      0.000       0.415       0.750
# contains_motorcycle_words    -0.0500      0.136     -0.367      0.713      -0.317       0.217
# hour                         -0.0145      0.004     -3.349      0.001      -0.023      -0.006
# day_of_week                  -0.0213      0.013     -1.596      0.110      -0.047       0.005
# month                         0.0147      0.008      1.854      0.064      -0.001       0.030
# =============================================================================================
# c:\Users\leovo\anaconda3\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %%
print("Negative Binomial AIC:", nb_results.aic)
# Out:
# Negative Binomial AIC: 8888.431669068581

# %%
import statsmodels.api as sm

X = df[['contains_pedestrian_words',
        'contains_matatu_words',
        'contains_motorcycle_words',
        'hour', 'day_of_week', 'month']]
X = sm.add_constant(X)
y = df['n_crash_reports']

poisson = sm.GLM(y, X, family=sm.families.Poisson()).fit()
nb = sm.GLM(y, X, family=sm.families.NegativeBinomial()).fit()

poisson.aic, nb.aic
# Out:
# c:\Users\leovo\anaconda3\Lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# (np.float64(8545.725738647212), np.float64(8888.431669068581))
